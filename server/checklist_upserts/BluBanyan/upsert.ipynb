# %%
import json
import pprint
import subprocess

import duckdb
import polars as pl

# %%
import os
import sys
import django

# Add your project root to the Python path if necessary
sys.path.append('/home/reepoi/GitHub/Orange-Button-ChecklistRegistry') 

os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
# Set the DJANGO_SETTINGS_MODULE environment variable
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'checklist.settings')

# Initialize Django
django.setup()

# %%
from server import models

# %% [markdown]
# ### Maintainer

# %%
maintainer, was_created = models.ChecklistTemplateMaintainer.objects.update_or_create(
    Email_Value='info@blubanyan.com',
    URL_Value='https://blubanyan.com',
    WorkPhone_Value='510.929.1070',
    ChecklistTemplateMaintainerName_Value='Blu Banyan',
)
f'{maintainer=}, {was_created=}'
# maintainer.save()
# Out:
# 'maintainer=<ChecklistTemplateMaintainer: ChecklistTemplateMaintainer object (1)>, was_created=True'

# %% [markdown]
# ### Upsert AnswerOptions
# The AnswerOption table should have a unique constaint on Value, and the columns of this table are id and Value. Value can be treated as an alternate key.

# %%
answer_option_groups = pl.read_csv('AnswerOptionGroups.2026-02-11.csv')
answer_option_groups = {
    col.name: [v for v in col if v is not None]
    for col in answer_option_groups
}
pprint.pp(answer_option_groups, compact=True)
# Out:
# {'Home Style': ['Single', '2 Story', '3 Story', 'Mobile', 'Condo/Townhome'],
#  'Roof Material': ['Cemented-Down Tile', 'Clay tile', 'Comp Shingle',
#                    'Concrete', 'Corrugated Metal', 'Elastomeric', 'Flat Tile',
#                    'Foam', 'Gravel', 'Metal Tile',
#                    'Not Applicable (No modules on the roof)', 'Rolled Asphalt',
#                    'S-Tile', 'Standing Seam Metal', 'TPO',
#                    'Unable To Determine', 'W-Tile', 'Wood shake'],
#  'Panel Manufacturer': ['Siemens/Murray/ITE/Gould/Crouse Hinds', 'Square D HOM',
#                         'Square D QO', 'Eaton BH/Cutler Hammer/Westinghouse',
#                         'Eaton BR/Challenger/Bryant',
#                         'General Electric/Milbank/Unicorn', 'Zinsco/Sylvania',
#                         'Federal Pacific', 'Not accessible'],
#  'Main Breaker Rating': ['225A', '400A', '200A', '300A', '175A', '250A', '150A',
#                          '125A', '100A', 'No Main Breaker',
#                          'Unable To Determine'],
#  'Bus Rating': ['225A', '200A', '250A', '150A', '125A', '100A', 'No Label',
#                 '400A', 'Unable To Determine'],
#  'Roof Pitch (Degrees)': ['5', '9', '14', '18', '22', '26', '30', '33', '37',
#                           '40', '42.5', '45',
#                           'Not Applicable (No modules on the roof)',
#                           'Unable To Determine'],
#  'Battery Capacity Types': ['N/A', 'Partial Backup', 'Full House Backup'],
#  'DC Wire Run/Panel Ready Info': ['Weather', 'Short laborers',
#                                   'On jobsite issues, (design, electrical)',
#                                   'Material shortage'],
#  'All Modules Landed Info list': ['Weather', 'Short laborers',
#                                   'Onsite fitment issues',
#                                   'Material shortage'],
#  'Ground Rods Installed list': ['Blue stake not called'],
#  'Electrical Equipment Hung L': ['No electrical lead',
#                                  'Material shortage (disco, meter and '
#                                  'inverter)',
#                                  'No access'],
#  'AC Wire Run Complete List': ['No electrical lead',
#                                'Pending main panel upgrade',
#                                'Material shortage (disco, meter, wire, '
#                                'breaker, fuses and inverter)'],
#  'DC Wire Run to Roof J-Box List': ['Short laborers', 'Weather',
#                                     'Time allotment on job'],
#  'All Labels Placed List': ['No electrical lead', 'Incorrect labels given'],
#  'All Strings Working List': ['Ran out of daylight', 'Time allotment on job'],
#  'Monitoring Set Up Tested List': ['No electrical lead',
#                                    'Time allotment on job'],
#  'Yes / No': ['Yes', 'No'],
#  'Yes / No / NA': ['Yes', 'No', 'NA'],
#  'Yes / No / Unknown': ['Yes', 'No', 'Unknown']}

# %%
for k, v in answer_option_groups.items():
    answer_option_groups[k] = [
        models.AnswerOption.objects.get_or_create(Value=vv)[0] for vv in v
    ]
pprint.pp(answer_option_groups, compact=True)
# Out:
# {'Home Style': [<AnswerOption: Single>, <AnswerOption: 2 Story>,
#                 <AnswerOption: 3 Story>, <AnswerOption: Mobile>,
#                 <AnswerOption: Condo/Townhome>],
#  'Roof Material': [<AnswerOption: Cemented-Down Tile>,
#                    <AnswerOption: Clay tile>, <AnswerOption: Comp Shingle>,
#                    <AnswerOption: Concrete>, <AnswerOption: Corrugated Metal>,
#                    <AnswerOption: Elastomeric>, <AnswerOption: Flat Tile>,
#                    <AnswerOption: Foam>, <AnswerOption: Gravel>,
#                    <AnswerOption: Metal Tile>,
#                    <AnswerOption: Not Applicable (No modules on the roof)>,
#                    <AnswerOption: Rolled Asphalt>, <AnswerOption: S-Tile>,
#                    <AnswerOption: Standing Seam Metal>, <AnswerOption: TPO>,
#                    <AnswerOption: Unable To Determine>, <AnswerOption: W-Tile>,
#                    <AnswerOption: Wood shake>],
#  'Panel Manufacturer': [<AnswerOption: Siemens/Murray/ITE/Gould/Crouse Hinds>,
#                         <AnswerOption: Square D HOM>,
#                         <AnswerOption: Square D QO>,
#                         <AnswerOption: Eaton BH/Cutler Hammer/Westinghouse>,
#                         <AnswerOption: Eaton BR/Challenger/Bryant>,
#                         <AnswerOption: General Electric/Milbank/Unicorn>,
#                         <AnswerOption: Zinsco/Sylvania>,
#                         <AnswerOption: Federal Pacific>,
#                         <AnswerOption: Not accessible>],
#  'Main Breaker Rating': [<AnswerOption: 225A>, <AnswerOption: 400A>,
#                          <AnswerOption: 200A>, <AnswerOption: 300A>,
#                          <AnswerOption: 175A>, <AnswerOption: 250A>,
#                          <AnswerOption: 150A>, <AnswerOption: 125A>,
#                          <AnswerOption: 100A>, <AnswerOption: No Main Breaker>,
#                          <AnswerOption: Unable To Determine>],
#  'Bus Rating': [<AnswerOption: 225A>, <AnswerOption: 200A>,
#                 <AnswerOption: 250A>, <AnswerOption: 150A>,
#                 <AnswerOption: 125A>, <AnswerOption: 100A>,
#                 <AnswerOption: No Label>, <AnswerOption: 400A>,
#                 <AnswerOption: Unable To Determine>],
#  'Roof Pitch (Degrees)': [<AnswerOption: 5>, <AnswerOption: 9>,
#                           <AnswerOption: 14>, <AnswerOption: 18>,
#                           <AnswerOption: 22>, <AnswerOption: 26>,
#                           <AnswerOption: 30>, <AnswerOption: 33>,
#                           <AnswerOption: 37>, <AnswerOption: 40>,
#                           <AnswerOption: 42.5>, <AnswerOption: 45>,
#                           <AnswerOption: Not Applicable (No modules on the roof)>,
#                           <AnswerOption: Unable To Determine>],
#  'Battery Capacity Types': [<AnswerOption: N/A>, <AnswerOption: Partial Backup>,
#                             <AnswerOption: Full House Backup>],
#  'DC Wire Run/Panel Ready Info': [<AnswerOption: Weather>,
#                                   <AnswerOption: Short laborers>,
#                                   <AnswerOption: On jobsite issues, (design, electrical)>,
#                                   <AnswerOption: Material shortage>],
#  'All Modules Landed Info list': [<AnswerOption: Weather>,
#                                   <AnswerOption: Short laborers>,
#                                   <AnswerOption: Onsite fitment issues>,
#                                   <AnswerOption: Material shortage>],
#  'Ground Rods Installed list': [<AnswerOption: Blue stake not called>],
#  'Electrical Equipment Hung L': [<AnswerOption: No electrical lead>,
#                                  <AnswerOption: Material shortage (disco, meter and inverter)>,
#                                  <AnswerOption: No access>],
#  'AC Wire Run Complete List': [<AnswerOption: No electrical lead>,
#                                <AnswerOption: Pending main panel upgrade>,
#                                <AnswerOption: Material shortage (disco, meter, wire, breaker, fuses and inverter)>],
#  'DC Wire Run to Roof J-Box List': [<AnswerOption: Short laborers>,
#                                     <AnswerOption: Weather>,
#                                     <AnswerOption: Time allotment on job>],
#  'All Labels Placed List': [<AnswerOption: No electrical lead>,
#                             <AnswerOption: Incorrect labels given>],
#  'All Strings Working List': [<AnswerOption: Ran out of daylight>,
#                               <AnswerOption: Time allotment on job>],
#  'Monitoring Set Up Tested List': [<AnswerOption: No electrical lead>,
#                                    <AnswerOption: Time allotment on job>],
#  'Yes / No': [<AnswerOption: Yes>, <AnswerOption: No>],
#  'Yes / No / NA': [<AnswerOption: Yes>, <AnswerOption: No>, <AnswerOption: NA>],
#  'Yes / No / Unknown': [<AnswerOption: Yes>, <AnswerOption: No>,
#                         <AnswerOption: Unknown>]}

# %% [markdown]
# ### Checklist Templates

# %%
checklist_template_questions = pl.read_csv('ChecklistTemplateQuestions.2026-02-11.csv')
checklist_template_questions
# Out:
# shape: (52, 9)
# ┌────────────┬───────────┬───────────┬───────────┬───┬───────────┬─────────┬───────────┬───────────┐
# │ Checklist  ┆ DisplaySe ┆ SectionNa ┆ Question  ┆ … ┆ For       ┆ Example ┆ Tag       ┆ Help Text │
# │ Template   ┆ qNumber   ┆ me        ┆ Label     ┆   ┆ Select    ┆ ---     ┆ ---       ┆ ---       │
# │ Name       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ there     ┆ str     ┆ str       ┆ str       │
# │ ---        ┆ i64       ┆ str       ┆ str       ┆   ┆ would be  ┆         ┆           ┆           │
# │ str        ┆           ┆           ┆           ┆   ┆ 'Ans…     ┆         ┆           ┆           │
# │            ┆           ┆           ┆           ┆   ┆ ---       ┆         ┆           ┆           │
# │            ┆           ┆           ┆           ┆   ┆ str       ┆         ┆           ┆           │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═════════╪═══════════╪═══════════╡
# │ Site       ┆ 10        ┆ Ground    ┆ Cancelled ┆ … ┆ Yes / No  ┆ null    ┆ Residenti ┆ Indicate  │
# │ Survey     ┆           ┆           ┆ at the    ┆   ┆           ┆         ┆ al        ┆ if the    │
# │            ┆           ┆           ┆ Door Y/N  ┆   ┆           ┆         ┆           ┆ homeowner │
# │            ┆           ┆           ┆           ┆   ┆           ┆         ┆           ┆ comm…     │
# │ Site       ┆ 20        ┆ Ground    ┆ Home Type ┆ … ┆ Home      ┆ null    ┆ Residenti ┆ Define    │
# │ Survey     ┆           ┆           ┆           ┆   ┆ Style     ┆         ┆ al        ┆ the home  │
# │            ┆           ┆           ┆           ┆   ┆           ┆         ┆           ┆ type      │
# │            ┆           ┆           ┆           ┆   ┆           ┆         ┆           ┆ (e.g.     │
# │            ┆           ┆           ┆           ┆   ┆           ┆         ┆           ┆ sin…      │
# │ Site       ┆ 30        ┆ Roof      ┆ Was       ┆ … ┆ Yes / No  ┆ null    ┆ Residenti ┆ Contact   │
# │ Survey     ┆           ┆           ┆ Layout    ┆   ┆           ┆         ┆ al        ┆ your supe │
# │            ┆           ┆           ┆ Provided  ┆   ┆           ┆         ┆           ┆ rvisor if │
# │            ┆           ┆           ┆ for       ┆   ┆           ┆         ┆           ┆ the…      │
# │            ┆           ┆           ┆ Survey    ┆   ┆           ┆         ┆           ┆           │
# │ Site       ┆ 40        ┆ Roof      ┆ Panels    ┆ … ┆ Yes / No  ┆ null    ┆ Residenti ┆ Indicate  │
# │ Survey     ┆           ┆           ┆ Proposed  ┆   ┆           ┆         ┆ al        ┆ if any    │
# │            ┆           ┆           ┆ on Additi ┆   ┆           ┆         ┆           ┆ solar     │
# │            ┆           ┆           ┆ onal …    ┆   ┆           ┆         ┆           ┆ panels a… │
# │ Site       ┆ 50        ┆ Roof      ┆ Roof      ┆ … ┆ Roof      ┆ null    ┆ Residenti ┆ Record    │
# │ Survey     ┆           ┆           ┆ Material  ┆   ┆ Material  ┆         ┆ al        ┆ the type  │
# │            ┆           ┆           ┆           ┆   ┆           ┆         ┆           ┆ of        │
# │            ┆           ┆           ┆           ┆   ┆           ┆         ┆           ┆ roofing   │
# │            ┆           ┆           ┆           ┆   ┆           ┆         ┆           ┆ mat…      │
# │ …          ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …       ┆ …         ┆ …         │
# │ Installati ┆ 480       ┆ Electrica ┆ Was A     ┆ … ┆ Yes / No  ┆ null    ┆ Residenti ┆ Indicate  │
# │ on         ┆           ┆ l Ground  ┆ Line Side ┆   ┆           ┆         ┆ al        ┆ if a supp │
# │            ┆           ┆           ┆ Tap       ┆   ┆           ┆         ┆           ┆ ly-side   │
# │            ┆           ┆           ┆ Completed ┆   ┆           ┆         ┆           ┆ (lin…     │
# │ Installati ┆ 490       ┆ Electrica ┆ Was A     ┆ … ┆ Yes / No  ┆ null    ┆ Residenti ┆ Indicate  │
# │ on         ┆           ┆ l Ground  ┆ Derate    ┆   ┆           ┆         ┆ al        ┆ if the    │
# │            ┆           ┆           ┆ Completed ┆   ┆           ┆         ┆           ┆ main      │
# │            ┆           ┆           ┆           ┆   ┆           ┆         ┆           ┆ breaker   │
# │            ┆           ┆           ┆           ┆   ┆           ┆         ┆           ┆ w…        │
# │ Installati ┆ 500       ┆ Electrica ┆ Was A     ┆ … ┆ Yes / No  ┆ null    ┆ Residenti ┆ Indicate  │
# │ on         ┆           ┆ l Ground  ┆ Hawaiian  ┆   ┆           ┆         ┆ al        ┆ if a Hawa │
# │            ┆           ┆           ┆ Tie In    ┆   ┆           ┆         ┆           ┆ iian-styl │
# │            ┆           ┆           ┆ Complete  ┆   ┆           ┆         ┆           ┆ e i…      │
# │ Installati ┆ 510       ┆ Electrica ┆ Was a     ┆ … ┆ Yes / No  ┆ null    ┆ Residenti ┆ Indicate  │
# │ on         ┆           ┆ l Ground  ┆ Meter     ┆   ┆           ┆         ┆ al        ┆ if a      │
# │            ┆           ┆           ┆ Collar    ┆   ┆           ┆         ┆           ┆ meter     │
# │            ┆           ┆           ┆ Adaptor   ┆   ┆           ┆         ┆           ┆ collar    │
# │            ┆           ┆           ┆ com…      ┆   ┆           ┆         ┆           ┆ ada…      │
# │ Installati ┆ 520       ┆ Ground    ┆ Installat ┆ … ┆ null      ┆ null    ┆ Residenti ┆ Enter the │
# │ on         ┆           ┆           ┆ ion Date  ┆   ┆           ┆         ┆ al        ┆ date when │
# │            ┆           ┆           ┆           ┆   ┆           ┆         ┆           ┆ the       │
# │            ┆           ┆           ┆           ┆   ┆           ┆         ┆           ┆ instal…   │
# └────────────┴───────────┴───────────┴───────────┴───┴───────────┴─────────┴───────────┴───────────┘

# %%
checklist_templates = []
for name in checklist_template_questions['Checklist Template Name'].unique():
    checklist_template, was_created = models.ChecklistTemplate.objects.update_or_create(
        ChecklistTemplateName_Value=name,
        ChecklistTemplateVersion_Value='1',
        ChecklistTemplateMaintainer=maintainer,
    )
    print(f'{checklist_template=}, {was_created=}')
    checklist_templates.append(checklist_template)
# Out:
# checklist_template=<ChecklistTemplate: ChecklistTemplate object (1)>, was_created=True
# checklist_template=<ChecklistTemplate: ChecklistTemplate object (2)>, was_created=True

# %% [markdown]
# ##### Questions

# %%
for template in checklist_templates:
    questions = checklist_template_questions.filter(pl.col('Checklist Template Name') == template.ChecklistTemplateName_Value)
    question_rows = []
    for row in questions.iter_rows(named=True):
        question = models.Question(
            AnswerType_Value=row['Answer Type'],
            DisplaySeqNumber_Value=row['DisplaySeqNumber'],
            QuestionHelp_Value=row['Help Text'],
            QuestionLabel_Value=row['Question Label'],
            SectionName_Value=row['SectionName'],
        )
        question.save()
        if row['Answer Type'] in ('EnumeratedSingle', 'EnumeratedMultiple'):
            answer_option_group = row["For Select there would be 'AnswerOption'"]
            question.AnswerOptions.set(answer_option_groups[answer_option_group])
        question_rows.append(question)
    template.Questions.set(question_rows)

# %% [markdown]
# ##### Tags
# The Tags table should have a unique constaint on Value, and the columns of this table are id and Value. Value can be treated as an alternate key.

# %%
for template in checklist_templates:
    tags = checklist_template_questions.filter(pl.col('Checklist Template Name') == template.ChecklistTemplateName_Value)['Tag'].unique()
    tags = [models.Tag.objects.get_or_create(Value=tag)[0] for tag in tags]
    template.Tags.set(tags)
